# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import polars as pl
import seaborn as sns
import scipy
from teeplot import teeplot as tp

# %%
teeplot_subdir = "adaptive-evolution-rate-nodirect.ipynb"

# %%
def load_and_process(url: str, mutation: str) -> pl.DataFrame:
    df = pl.read_parquet(
        url,
        use_pyarrow=True,
    ).with_columns(
        pl.col("SLIP_INSERTION_BOOL_MASK").any().over(
            ["Treatment", "Run ID", "Generation Born"],
        ).alias("SLIP_INSERTION_BOOL_MASK any"),
    ).group_by(
        ["Task", "Treatment", "Run ID", "Generation Born"],
    ).first().with_columns(
        pl.col("Task").replace_strict(
            {
                "AND": 2,
                "ANDNOT": 3,
                "NAND": 1,
                "NOR": 4,
                "NOT": 1,
                "OR": 3,
                "ORNOT": 2,
                "XOR": 4,
                "EQUALS": 5,
            },
        ).alias("Components"),
        pl.lit(mutation).alias("Mutation"),
    )

    return df

# %%
df1 = load_and_process("https://osf.io/emh23/download", "poisson")
# Out:
# sys:1: CategoricalRemappingWarning: Local categoricals have different encodings, expensive re-encoding is done to perform this merge operation. Consider using a StringCache or an Enum type if the categories are known in advance

# %%
df2 = load_and_process("https://osf.io/gk2ty/download", "per site")

# %%
df = pl.concat([df1, df2])
df
# Out:
# shape: (304_254, 34)
# ┌────────┬─────────────┬──────────┬─────────────┬───┬────────┬─────────────┬────────────┬──────────┐
# │ Task   ┆ Treatment   ┆ Run ID   ┆ Generation  ┆ … ┆ Update ┆ SLIP_INSERT ┆ Components ┆ Mutation │
# │ ---    ┆ ---         ┆ ---      ┆ Born        ┆   ┆ Born   ┆ ION_BOOL_MA ┆ ---        ┆ ---      │
# │ cat    ┆ cat         ┆ cat      ┆ ---         ┆   ┆ ---    ┆ SK any      ┆ i64        ┆ str      │
# │        ┆             ┆          ┆ u16         ┆   ┆ i32    ┆ ---         ┆            ┆          │
# │        ┆             ┆          ┆             ┆   ┆        ┆ bool        ┆            ┆          │
# ╞════════╪═════════════╪══════════╪═════════════╪═══╪════════╪═════════════╪════════════╪══════════╡
# │ OR     ┆ Slip-       ┆ run_1827 ┆ 706         ┆ … ┆ 7713   ┆ false       ┆ 3          ┆ poisson  │
# │ ANDNOT ┆ Slip+       ┆ run_1852 ┆ 401         ┆ … ┆ 18358  ┆ false       ┆ 3          ┆ poisson  │
# │ ORNOT  ┆ Slip-       ┆ run_1806 ┆ 1486        ┆ … ┆ 12113  ┆ false       ┆ 2          ┆ poisson  │
# │ NOR    ┆ Slip+       ┆ run_1847 ┆ 510         ┆ … ┆ 27407  ┆ true        ┆ 4          ┆ poisson  │
# │ AND    ┆ Slip-       ┆ run_1821 ┆ 4684        ┆ … ┆ 30562  ┆ false       ┆ 2          ┆ poisson  │
# │ …      ┆ …           ┆ …        ┆ …           ┆ … ┆ …      ┆ …           ┆ …          ┆ …        │
# │ OR     ┆ Slip-duplic ┆ run_1608 ┆ 648         ┆ … ┆ 24516  ┆ false       ┆ 3          ┆ per site │
# │        ┆ ate         ┆          ┆             ┆   ┆        ┆             ┆            ┆          │
# │ NAND   ┆ Slip-duplic ┆ run_1595 ┆ 807         ┆ … ┆ 36282  ┆ false       ┆ 1          ┆ per site │
# │        ┆ ate         ┆          ┆             ┆   ┆        ┆             ┆            ┆          │
# │ AND    ┆ Slip-duplic ┆ run_1610 ┆ 957         ┆ … ┆ 31459  ┆ false       ┆ 2          ┆ per site │
# │        ┆ ate         ┆          ┆             ┆   ┆        ┆             ┆            ┆          │
# │ AND    ┆ Long-Ancest ┆ run_1740 ┆ 235         ┆ … ┆ 16326  ┆ false       ┆ 2          ┆ per site │
# │        ┆ or-Control- ┆          ┆             ┆   ┆        ┆             ┆            ┆          │
# │        ┆ Treatmen…   ┆          ┆             ┆   ┆        ┆             ┆            ┆          │
# │ ANDNOT ┆ Slip-duplic ┆ run_1617 ┆ 407         ┆ … ┆ 11058  ┆ false       ┆ 3          ┆ per site │
# │        ┆ ate         ┆          ┆             ┆   ┆        ┆             ┆            ┆          │
# └────────┴─────────────┴──────────┴─────────────┴───┴────────┴─────────────┴────────────┴──────────┘

# %%
df = df.with_columns(
    (
        pl.col("Generation Born")
        + 0 / pl.col("has task")
    ).min().over(
        ["Treatment", "Run ID", "Mutation", "Task"],
    ).alias("First Task Generation"),
    pl.col("Generation Born").max().over(
        ["Treatment", "Run ID", "Mutation"]
    ).alias("Last Generation"),
)
df
# Out:
# shape: (304_254, 36)
# ┌────────┬────────────┬──────────┬────────────┬───┬────────────┬──────────┬────────────┬───────────┐
# │ Task   ┆ Treatment  ┆ Run ID   ┆ Generation ┆ … ┆ Components ┆ Mutation ┆ First Task ┆ Last Gene │
# │ ---    ┆ ---        ┆ ---      ┆ Born       ┆   ┆ ---        ┆ ---      ┆ Generation ┆ ration    │
# │ cat    ┆ cat        ┆ cat      ┆ ---        ┆   ┆ i64        ┆ str      ┆ ---        ┆ ---       │
# │        ┆            ┆          ┆ u16        ┆   ┆            ┆          ┆ f64        ┆ u16       │
# ╞════════╪════════════╪══════════╪════════════╪═══╪════════════╪══════════╪════════════╪═══════════╡
# │ OR     ┆ Slip-      ┆ run_1827 ┆ 706        ┆ … ┆ 3          ┆ poisson  ┆ 408.0      ┆ 6763      │
# │ ANDNOT ┆ Slip+      ┆ run_1852 ┆ 401        ┆ … ┆ 3          ┆ poisson  ┆ 200.0      ┆ 678       │
# │ ORNOT  ┆ Slip-      ┆ run_1806 ┆ 1486       ┆ … ┆ 2          ┆ poisson  ┆ 573.0      ┆ 7251      │
# │ NOR    ┆ Slip+      ┆ run_1847 ┆ 510        ┆ … ┆ 4          ┆ poisson  ┆ 210.0      ┆ 717       │
# │ AND    ┆ Slip-      ┆ run_1821 ┆ 4684       ┆ … ┆ 2          ┆ poisson  ┆ 3186.0     ┆ 7485      │
# │ …      ┆ …          ┆ …        ┆ …          ┆ … ┆ …          ┆ …        ┆ …          ┆ …         │
# │ OR     ┆ Slip-dupli ┆ run_1608 ┆ 648        ┆ … ┆ 3          ┆ per site ┆ 166.0      ┆ 1062      │
# │        ┆ cate       ┆          ┆            ┆   ┆            ┆          ┆            ┆           │
# │ NAND   ┆ Slip-dupli ┆ run_1595 ┆ 807        ┆ … ┆ 1          ┆ per site ┆ 97.0       ┆ 1004      │
# │        ┆ cate       ┆          ┆            ┆   ┆            ┆          ┆            ┆           │
# │ AND    ┆ Slip-dupli ┆ run_1610 ┆ 957        ┆ … ┆ 2          ┆ per site ┆ 180.0      ┆ 1263      │
# │        ┆ cate       ┆          ┆            ┆   ┆            ┆          ┆            ┆           │
# │ AND    ┆ Long-Ances ┆ run_1740 ┆ 235        ┆ … ┆ 2          ┆ per site ┆ 69.0       ┆ 700       │
# │        ┆ tor-Contro ┆          ┆            ┆   ┆            ┆          ┆            ┆           │
# │        ┆ l-Treatmen ┆          ┆            ┆   ┆            ┆          ┆            ┆           │
# │        ┆ …          ┆          ┆            ┆   ┆            ┆          ┆            ┆           │
# │ ANDNOT ┆ Slip-dupli ┆ run_1617 ┆ 407        ┆ … ┆ 3          ┆ per site ┆ 134.0      ┆ 1085      │
# │        ┆ cate       ┆          ┆            ┆   ┆            ┆          ┆            ┆           │
# └────────┴────────────┴──────────┴────────────┴───┴────────────┴──────────┴────────────┴───────────┘

# %%
df.group_by(
    ["Treatment", "Mutation"],
).agg(
    pl.col("Last Generation").min(),
)
# Out:
# shape: (6, 3)
# ┌─────────────────────────────────┬──────────┬─────────────────┐
# │ Treatment                       ┆ Mutation ┆ Last Generation │
# │ ---                             ┆ ---      ┆ ---             │
# │ cat                             ┆ str      ┆ u16             │
# ╞═════════════════════════════════╪══════════╪═════════════════╡
# │ Baseline-Treatment              ┆ per site ┆ 4081            │
# │ Long-Ancestor-Control-Treatmen… ┆ per site ┆ 538             │
# │ Slip-                           ┆ poisson  ┆ 2050            │
# │ Slip-_Long                      ┆ poisson  ┆ 340             │
# │ Slip-duplicate                  ┆ per site ┆ 901             │
# │ Slip+                           ┆ poisson  ┆ 573             │
# └─────────────────────────────────┴──────────┴─────────────────┘

# %%
least_last_generation = 600
least_last_generation
# Out:
# 600

# %%
dfz = df.filter(
    # (pl.col("Generation Born") <= least_last_generation)
    pl.col("has task")
    & (pl.col("delta has task") == 1)
    & (pl.col("First Task Generation") == pl.col("Generation Born"))
    & (
        (pl.col("Treatment") != "Slip-duplicate")
        | (~pl.col("SLIP_INSERTION_BOOL_MASK any"))
    )
).group_by(
    ["Task", "Treatment", "Run ID", "Components", "Mutation"],
).agg(
    pl.col("Generation Born").min(),
)
dfz
# Out:
# shape: (1_103, 6)
# ┌────────┬─────────────────────────────────┬──────────┬────────────┬──────────┬─────────────────┐
# │ Task   ┆ Treatment                       ┆ Run ID   ┆ Components ┆ Mutation ┆ Generation Born │
# │ ---    ┆ ---                             ┆ ---      ┆ ---        ┆ ---      ┆ ---             │
# │ cat    ┆ cat                             ┆ cat      ┆ i64        ┆ str      ┆ u16             │
# ╞════════╪═════════════════════════════════╪══════════╪════════════╪══════════╪═════════════════╡
# │ AND    ┆ Slip-                           ┆ run_1811 ┆ 2          ┆ poisson  ┆ 2372            │
# │ NOT    ┆ Slip+                           ┆ run_1838 ┆ 1          ┆ poisson  ┆ 143             │
# │ OR     ┆ Long-Ancestor-Control-Treatmen… ┆ run_1748 ┆ 3          ┆ per site ┆ 61              │
# │ ANDNOT ┆ Long-Ancestor-Control-Treatmen… ┆ run_1764 ┆ 3          ┆ per site ┆ 81              │
# │ NAND   ┆ Slip+                           ┆ run_1840 ┆ 1          ┆ poisson  ┆ 91              │
# │ …      ┆ …                               ┆ …        ┆ …          ┆ …        ┆ …               │
# │ ORNOT  ┆ Baseline-Treatment              ┆ run_1551 ┆ 2          ┆ per site ┆ 335             │
# │ NAND   ┆ Baseline-Treatment              ┆ run_1549 ┆ 1          ┆ per site ┆ 136             │
# │ NOT    ┆ Baseline-Treatment              ┆ run_1546 ┆ 1          ┆ per site ┆ 225             │
# │ NAND   ┆ Slip-                           ┆ run_1804 ┆ 1          ┆ poisson  ┆ 248             │
# │ ORNOT  ┆ Long-Ancestor-Control-Treatmen… ┆ run_1755 ┆ 2          ┆ per site ┆ 73              │
# └────────┴─────────────────────────────────┴──────────┴────────────┴──────────┴─────────────────┘

# %%
dfz
# Out:
# shape: (1_103, 6)
# ┌────────┬─────────────────────────────────┬──────────┬────────────┬──────────┬─────────────────┐
# │ Task   ┆ Treatment                       ┆ Run ID   ┆ Components ┆ Mutation ┆ Generation Born │
# │ ---    ┆ ---                             ┆ ---      ┆ ---        ┆ ---      ┆ ---             │
# │ cat    ┆ cat                             ┆ cat      ┆ i64        ┆ str      ┆ u16             │
# ╞════════╪═════════════════════════════════╪══════════╪════════════╪══════════╪═════════════════╡
# │ AND    ┆ Slip-                           ┆ run_1811 ┆ 2          ┆ poisson  ┆ 2372            │
# │ NOT    ┆ Slip+                           ┆ run_1838 ┆ 1          ┆ poisson  ┆ 143             │
# │ OR     ┆ Long-Ancestor-Control-Treatmen… ┆ run_1748 ┆ 3          ┆ per site ┆ 61              │
# │ ANDNOT ┆ Long-Ancestor-Control-Treatmen… ┆ run_1764 ┆ 3          ┆ per site ┆ 81              │
# │ NAND   ┆ Slip+                           ┆ run_1840 ┆ 1          ┆ poisson  ┆ 91              │
# │ …      ┆ …                               ┆ …        ┆ …          ┆ …        ┆ …               │
# │ ORNOT  ┆ Baseline-Treatment              ┆ run_1551 ┆ 2          ┆ per site ┆ 335             │
# │ NAND   ┆ Baseline-Treatment              ┆ run_1549 ┆ 1          ┆ per site ┆ 136             │
# │ NOT    ┆ Baseline-Treatment              ┆ run_1546 ┆ 1          ┆ per site ┆ 225             │
# │ NAND   ┆ Slip-                           ┆ run_1804 ┆ 1          ┆ poisson  ┆ 248             │
# │ ORNOT  ┆ Long-Ancestor-Control-Treatmen… ┆ run_1755 ┆ 2          ┆ per site ┆ 73              │
# └────────┴─────────────────────────────────┴──────────┴────────────┴──────────┴─────────────────┘

# %%
maxgen = dfz["Generation Born"].max()

records = []
records2 = set()
for row in dfz.iter_rows(named=True):
    records.append(
        pd.DataFrame(
            {
                "Task": row["Task"],
                "Treatment": row["Treatment"],
                "Run ID": row["Run ID"],
                "Generation": np.arange(maxgen),
                "Components": row["Components"],
                "Has Task":  row["Generation Born"] <= np.arange(maxgen),
                "mutation": row["Mutation"],
            },
        ),
    )
    records2.add(
        (row["Run ID"], row["Treatment"], row["Task"], row["Components"], row["Mutation"]),
    )

for v, grp in df.to_pandas().groupby(
    ["Run ID", "Treatment", "Task", "Components", "Mutation"],
    observed=True,
):
    if v not in records2:
        print(v)
        records.append(
            pd.DataFrame(
                {
                    "Task": v[2],
                    "Treatment": v[1],
                    "Run ID": v[0],
                    "Components": v[3],
                    "Generation": np.arange(maxgen),
                    "Has Task":  False,
                    "mutation": v[4],
                },
            ),
        )

dfz_ = pd.concat(records, ignore_index=True)
# Out:
# ('run_1770', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1770', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1770', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1770', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1771', 'Slip-_Long', 'AND', np.int64(2), 'poisson')
# ('run_1771', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1771', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1771', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1771', 'Slip-_Long', 'OR', np.int64(3), 'poisson')
# ('run_1771', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1772', 'Slip-_Long', 'AND', np.int64(2), 'poisson')
# ('run_1772', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1772', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1772', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1772', 'Slip-_Long', 'NOT', np.int64(1), 'poisson')
# ('run_1772', 'Slip-_Long', 'OR', np.int64(3), 'poisson')
# ('run_1772', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1773', 'Slip-_Long', 'AND', np.int64(2), 'poisson')
# ('run_1773', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1773', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1773', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1773', 'Slip-_Long', 'OR', np.int64(3), 'poisson')
# ('run_1773', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1774', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1774', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1774', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1774', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1775', 'Slip-_Long', 'AND', np.int64(2), 'poisson')
# ('run_1775', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1775', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1775', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1775', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1776', 'Slip-_Long', 'AND', np.int64(2), 'poisson')
# ('run_1776', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1776', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1776', 'Slip-_Long', 'NAND', np.int64(1), 'poisson')
# ('run_1776', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1776', 'Slip-_Long', 'OR', np.int64(3), 'poisson')
# ('run_1776', 'Slip-_Long', 'ORNOT', np.int64(2), 'poisson')
# ('run_1776', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1777', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1777', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1777', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1777', 'Slip-_Long', 'OR', np.int64(3), 'poisson')
# ('run_1777', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1778', 'Slip-_Long', 'AND', np.int64(2), 'poisson')
# ('run_1778', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1778', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1778', 'Slip-_Long', 'NAND', np.int64(1), 'poisson')
# ('run_1778', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1778', 'Slip-_Long', 'OR', np.int64(3), 'poisson')
# ('run_1778', 'Slip-_Long', 'ORNOT', np.int64(2), 'poisson')
# ('run_1778', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1779', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1779', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1779', 'Slip-_Long', 'OR', np.int64(3), 'poisson')
# ('run_1779', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1780', 'Slip-_Long', 'AND', np.int64(2), 'poisson')
# ('run_1780', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1780', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1780', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1780', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1781', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1781', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1781', 'Slip-_Long', 'OR', np.int64(3), 'poisson')
# ('run_1781', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1782', 'Slip-_Long', 'AND', np.int64(2), 'poisson')
# ('run_1782', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1782', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1782', 'Slip-_Long', 'NAND', np.int64(1), 'poisson')
# ('run_1782', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1782', 'Slip-_Long', 'OR', np.int64(3), 'poisson')
# ('run_1782', 'Slip-_Long', 'ORNOT', np.int64(2), 'poisson')
# ('run_1782', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1783', 'Slip-_Long', 'AND', np.int64(2), 'poisson')
# ('run_1783', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1783', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1783', 'Slip-_Long', 'NAND', np.int64(1), 'poisson')
# ('run_1783', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1783', 'Slip-_Long', 'NOT', np.int64(1), 'poisson')
# ('run_1783', 'Slip-_Long', 'OR', np.int64(3), 'poisson')
# ('run_1783', 'Slip-_Long', 'ORNOT', np.int64(2), 'poisson')
# ('run_1783', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1784', 'Slip-_Long', 'AND', np.int64(2), 'poisson')
# ('run_1784', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1784', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1784', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1784', 'Slip-_Long', 'OR', np.int64(3), 'poisson')
# ('run_1784', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1785', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1785', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1785', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1785', 'Slip-_Long', 'OR', np.int64(3), 'poisson')
# ('run_1785', 'Slip-_Long', 'ORNOT', np.int64(2), 'poisson')
# ('run_1785', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1786', 'Slip-_Long', 'AND', np.int64(2), 'poisson')
# ('run_1786', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1786', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1786', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1786', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1787', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1787', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1787', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1787', 'Slip-_Long', 'OR', np.int64(3), 'poisson')
# ('run_1787', 'Slip-_Long', 'ORNOT', np.int64(2), 'poisson')
# ('run_1787', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1788', 'Slip-_Long', 'AND', np.int64(2), 'poisson')
# ('run_1788', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1788', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1788', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1788', 'Slip-_Long', 'OR', np.int64(3), 'poisson')
# ('run_1788', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1789', 'Slip-_Long', 'AND', np.int64(2), 'poisson')
# ('run_1789', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1789', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1789', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1789', 'Slip-_Long', 'OR', np.int64(3), 'poisson')
# ('run_1789', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1790', 'Slip-_Long', 'AND', np.int64(2), 'poisson')
# ('run_1790', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1790', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1790', 'Slip-_Long', 'NAND', np.int64(1), 'poisson')
# ('run_1790', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1790', 'Slip-_Long', 'OR', np.int64(3), 'poisson')
# ('run_1790', 'Slip-_Long', 'ORNOT', np.int64(2), 'poisson')
# ('run_1790', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1791', 'Slip-_Long', 'AND', np.int64(2), 'poisson')
# ('run_1791', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1791', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1791', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1791', 'Slip-_Long', 'OR', np.int64(3), 'poisson')
# ('run_1791', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1792', 'Slip-_Long', 'AND', np.int64(2), 'poisson')
# ('run_1792', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1792', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1792', 'Slip-_Long', 'NAND', np.int64(1), 'poisson')
# ('run_1792', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1792', 'Slip-_Long', 'OR', np.int64(3), 'poisson')
# ('run_1792', 'Slip-_Long', 'ORNOT', np.int64(2), 'poisson')
# ('run_1792', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1793', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1793', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1793', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1794', 'Slip-_Long', 'AND', np.int64(2), 'poisson')
# ('run_1794', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1794', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1794', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1794', 'Slip-_Long', 'OR', np.int64(3), 'poisson')
# ('run_1794', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1795', 'Slip-_Long', 'AND', np.int64(2), 'poisson')
# ('run_1795', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1795', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1795', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1795', 'Slip-_Long', 'NOT', np.int64(1), 'poisson')
# ('run_1795', 'Slip-_Long', 'OR', np.int64(3), 'poisson')
# ('run_1795', 'Slip-_Long', 'ORNOT', np.int64(2), 'poisson')
# ('run_1795', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1796', 'Slip-_Long', 'AND', np.int64(2), 'poisson')
# ('run_1796', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1796', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1796', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1796', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1797', 'Slip-_Long', 'AND', np.int64(2), 'poisson')
# ('run_1797', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1797', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1797', 'Slip-_Long', 'NAND', np.int64(1), 'poisson')
# ('run_1797', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1797', 'Slip-_Long', 'OR', np.int64(3), 'poisson')
# ('run_1797', 'Slip-_Long', 'ORNOT', np.int64(2), 'poisson')
# ('run_1797', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1798', 'Slip-_Long', 'AND', np.int64(2), 'poisson')
# ('run_1798', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1798', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1798', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1798', 'Slip-_Long', 'OR', np.int64(3), 'poisson')
# ('run_1798', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1799', 'Slip-_Long', 'AND', np.int64(2), 'poisson')
# ('run_1799', 'Slip-_Long', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1799', 'Slip-_Long', 'EQUALS', np.int64(5), 'poisson')
# ('run_1799', 'Slip-_Long', 'NOR', np.int64(4), 'poisson')
# ('run_1799', 'Slip-_Long', 'OR', np.int64(3), 'poisson')
# ('run_1799', 'Slip-_Long', 'XOR', np.int64(4), 'poisson')
# ('run_1800', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1800', 'Slip-', 'NOR', np.int64(4), 'poisson')
# ('run_1800', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1801', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1801', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1802', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1803', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1803', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1804', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1804', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1805', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1805', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1806', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1806', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1807', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1807', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1808', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1808', 'Slip-', 'NOR', np.int64(4), 'poisson')
# ('run_1808', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1810', 'Slip-', 'AND', np.int64(2), 'poisson')
# ('run_1810', 'Slip-', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1810', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1810', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1811', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1811', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1812', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1812', 'Slip-', 'NOR', np.int64(4), 'poisson')
# ('run_1812', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1813', 'Slip-', 'NOR', np.int64(4), 'poisson')
# ('run_1814', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1814', 'Slip-', 'OR', np.int64(3), 'poisson')
# ('run_1814', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1815', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1815', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1816', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1816', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1817', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1817', 'Slip-', 'NOR', np.int64(4), 'poisson')
# ('run_1817', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1818', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1818', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1819', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1819', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1820', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1820', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1821', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1822', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1822', 'Slip-', 'NOR', np.int64(4), 'poisson')
# ('run_1822', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1823', 'Slip-', 'AND', np.int64(2), 'poisson')
# ('run_1823', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1823', 'Slip-', 'NOR', np.int64(4), 'poisson')
# ('run_1823', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1824', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1824', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1825', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1825', 'Slip-', 'NOR', np.int64(4), 'poisson')
# ('run_1825', 'Slip-', 'OR', np.int64(3), 'poisson')
# ('run_1825', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1826', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1826', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1827', 'Slip-', 'AND', np.int64(2), 'poisson')
# ('run_1827', 'Slip-', 'ANDNOT', np.int64(3), 'poisson')
# ('run_1827', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1827', 'Slip-', 'NOR', np.int64(4), 'poisson')
# ('run_1827', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1828', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1828', 'Slip-', 'NOR', np.int64(4), 'poisson')
# ('run_1828', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1829', 'Slip-', 'EQUALS', np.int64(5), 'poisson')
# ('run_1829', 'Slip-', 'NOR', np.int64(4), 'poisson')
# ('run_1829', 'Slip-', 'XOR', np.int64(4), 'poisson')
# ('run_1831', 'Slip+', 'EQUALS', np.int64(5), 'poisson')
# ('run_1831', 'Slip+', 'XOR', np.int64(4), 'poisson')
# ('run_1833', 'Slip+', 'EQUALS', np.int64(5), 'poisson')
# ('run_1833', 'Slip+', 'NOR', np.int64(4), 'poisson')
# ('run_1833', 'Slip+', 'XOR', np.int64(4), 'poisson')
# ('run_1836', 'Slip+', 'EQUALS', np.int64(5), 'poisson')
# ('run_1836', 'Slip+', 'XOR', np.int64(4), 'poisson')
# ('run_1839', 'Slip+', 'EQUALS', np.int64(5), 'poisson')
# ('run_1839', 'Slip+', 'XOR', np.int64(4), 'poisson')
# ('run_1840', 'Slip+', 'XOR', np.int64(4), 'poisson')
# ('run_1841', 'Slip+', 'EQUALS', np.int64(5), 'poisson')
# ('run_1841', 'Slip+', 'NOR', np.int64(4), 'poisson')
# ('run_1842', 'Slip+', 'EQUALS', np.int64(5), 'poisson')
# ('run_1842', 'Slip+', 'NOR', np.int64(4), 'poisson')
# ('run_1842', 'Slip+', 'OR', np.int64(3), 'poisson')
# ('run_1842', 'Slip+', 'XOR', np.int64(4), 'poisson')
# ('run_1843', 'Slip+', 'EQUALS', np.int64(5), 'poisson')
# ('run_1843', 'Slip+', 'XOR', np.int64(4), 'poisson')
# ('run_1844', 'Slip+', 'EQUALS', np.int64(5), 'poisson')
# ('run_1844', 'Slip+', 'XOR', np.int64(4), 'poisson')
# ('run_1845', 'Slip+', 'EQUALS', np.int64(5), 'poisson')
# ('run_1845', 'Slip+', 'XOR', np.int64(4), 'poisson')
# ('run_1848', 'Slip+', 'XOR', np.int64(4), 'poisson')
# ('run_1849', 'Slip+', 'EQUALS', np.int64(5), 'poisson')
# ('run_1851', 'Slip+', 'EQUALS', np.int64(5), 'poisson')
# ('run_1851', 'Slip+', 'XOR', np.int64(4), 'poisson')
# ('run_1852', 'Slip+', 'EQUALS', np.int64(5), 'poisson')
# ('run_1854', 'Slip+', 'XOR', np.int64(4), 'poisson')
# ('run_1858', 'Slip+', 'XOR', np.int64(4), 'poisson')
# ('run_1859', 'Slip+', 'EQUALS', np.int64(5), 'poisson')
# ('run_1859', 'Slip+', 'XOR', np.int64(4), 'poisson')
# ('run_1530', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1530', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1531', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1531', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1532', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1532', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1533', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1533', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1534', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1534', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1535', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1535', 'Baseline-Treatment', 'NOR', np.int64(4), 'per site')
# ('run_1535', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1536', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1536', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1537', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1537', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1538', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1538', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1539', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1540', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1540', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1541', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1541', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1542', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1542', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1543', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1543', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1544', 'Baseline-Treatment', 'AND', np.int64(2), 'per site')
# ('run_1544', 'Baseline-Treatment', 'NOR', np.int64(4), 'per site')
# ('run_1545', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1545', 'Baseline-Treatment', 'NOR', np.int64(4), 'per site')
# ('run_1545', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1546', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1546', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1547', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1547', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1548', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1548', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1549', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1549', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1550', 'Baseline-Treatment', 'AND', np.int64(2), 'per site')
# ('run_1550', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1550', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1551', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1551', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1552', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1552', 'Baseline-Treatment', 'NOR', np.int64(4), 'per site')
# ('run_1552', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1553', 'Baseline-Treatment', 'AND', np.int64(2), 'per site')
# ('run_1553', 'Baseline-Treatment', 'ANDNOT', np.int64(3), 'per site')
# ('run_1553', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1553', 'Baseline-Treatment', 'NOR', np.int64(4), 'per site')
# ('run_1553', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1554', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1554', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1555', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1555', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1556', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1556', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1557', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1557', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1558', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1558', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1559', 'Baseline-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1559', 'Baseline-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1590', 'Slip-duplicate', 'AND', np.int64(2), 'per site')
# ('run_1590', 'Slip-duplicate', 'NOT', np.int64(1), 'per site')
# ('run_1590', 'Slip-duplicate', 'OR', np.int64(3), 'per site')
# ('run_1591', 'Slip-duplicate', 'EQUALS', np.int64(5), 'per site')
# ('run_1591', 'Slip-duplicate', 'NOR', np.int64(4), 'per site')
# ('run_1591', 'Slip-duplicate', 'ORNOT', np.int64(2), 'per site')
# ('run_1591', 'Slip-duplicate', 'XOR', np.int64(4), 'per site')
# ('run_1592', 'Slip-duplicate', 'ANDNOT', np.int64(3), 'per site')
# ('run_1592', 'Slip-duplicate', 'EQUALS', np.int64(5), 'per site')
# ('run_1592', 'Slip-duplicate', 'NAND', np.int64(1), 'per site')
# ('run_1592', 'Slip-duplicate', 'XOR', np.int64(4), 'per site')
# ('run_1593', 'Slip-duplicate', 'EQUALS', np.int64(5), 'per site')
# ('run_1593', 'Slip-duplicate', 'XOR', np.int64(4), 'per site')
# ('run_1594', 'Slip-duplicate', 'EQUALS', np.int64(5), 'per site')
# ('run_1594', 'Slip-duplicate', 'NOR', np.int64(4), 'per site')
# ('run_1594', 'Slip-duplicate', 'NOT', np.int64(1), 'per site')
# ('run_1594', 'Slip-duplicate', 'OR', np.int64(3), 'per site')
# ('run_1594', 'Slip-duplicate', 'ORNOT', np.int64(2), 'per site')
# ('run_1595', 'Slip-duplicate', 'OR', np.int64(3), 'per site')
# ('run_1595', 'Slip-duplicate', 'ORNOT', np.int64(2), 'per site')
# ('run_1595', 'Slip-duplicate', 'XOR', np.int64(4), 'per site')
# ('run_1596', 'Slip-duplicate', 'EQUALS', np.int64(5), 'per site')
# ('run_1596', 'Slip-duplicate', 'NAND', np.int64(1), 'per site')
# ('run_1596', 'Slip-duplicate', 'NOT', np.int64(1), 'per site')
# ('run_1597', 'Slip-duplicate', 'NAND', np.int64(1), 'per site')
# ('run_1597', 'Slip-duplicate', 'ORNOT', np.int64(2), 'per site')
# ('run_1597', 'Slip-duplicate', 'XOR', np.int64(4), 'per site')
# ('run_1598', 'Slip-duplicate', 'NAND', np.int64(1), 'per site')
# ('run_1598', 'Slip-duplicate', 'ORNOT', np.int64(2), 'per site')
# ('run_1598', 'Slip-duplicate', 'XOR', np.int64(4), 'per site')
# ('run_1599', 'Slip-duplicate', 'EQUALS', np.int64(5), 'per site')
# ('run_1599', 'Slip-duplicate', 'NOT', np.int64(1), 'per site')
# ('run_1600', 'Slip-duplicate', 'NAND', np.int64(1), 'per site')
# ('run_1600', 'Slip-duplicate', 'OR', np.int64(3), 'per site')
# ('run_1600', 'Slip-duplicate', 'ORNOT', np.int64(2), 'per site')
# ('run_1601', 'Slip-duplicate', 'EQUALS', np.int64(5), 'per site')
# ('run_1601', 'Slip-duplicate', 'XOR', np.int64(4), 'per site')
# ('run_1602', 'Slip-duplicate', 'AND', np.int64(2), 'per site')
# ('run_1602', 'Slip-duplicate', 'ANDNOT', np.int64(3), 'per site')
# ('run_1602', 'Slip-duplicate', 'EQUALS', np.int64(5), 'per site')
# ('run_1602', 'Slip-duplicate', 'NAND', np.int64(1), 'per site')
# ('run_1602', 'Slip-duplicate', 'NOR', np.int64(4), 'per site')
# ('run_1602', 'Slip-duplicate', 'NOT', np.int64(1), 'per site')
# ('run_1602', 'Slip-duplicate', 'OR', np.int64(3), 'per site')
# ('run_1603', 'Slip-duplicate', 'EQUALS', np.int64(5), 'per site')
# ('run_1603', 'Slip-duplicate', 'OR', np.int64(3), 'per site')
# ('run_1603', 'Slip-duplicate', 'XOR', np.int64(4), 'per site')
# ('run_1604', 'Slip-duplicate', 'AND', np.int64(2), 'per site')
# ('run_1604', 'Slip-duplicate', 'EQUALS', np.int64(5), 'per site')
# ('run_1605', 'Slip-duplicate', 'AND', np.int64(2), 'per site')
# ('run_1605', 'Slip-duplicate', 'ANDNOT', np.int64(3), 'per site')
# ('run_1605', 'Slip-duplicate', 'EQUALS', np.int64(5), 'per site')
# ('run_1605', 'Slip-duplicate', 'NOR', np.int64(4), 'per site')
# ('run_1605', 'Slip-duplicate', 'XOR', np.int64(4), 'per site')
# ('run_1606', 'Slip-duplicate', 'AND', np.int64(2), 'per site')
# ('run_1606', 'Slip-duplicate', 'ANDNOT', np.int64(3), 'per site')
# ('run_1606', 'Slip-duplicate', 'NAND', np.int64(1), 'per site')
# ('run_1606', 'Slip-duplicate', 'NOR', np.int64(4), 'per site')
# ('run_1606', 'Slip-duplicate', 'NOT', np.int64(1), 'per site')
# ('run_1606', 'Slip-duplicate', 'ORNOT', np.int64(2), 'per site')
# ('run_1606', 'Slip-duplicate', 'XOR', np.int64(4), 'per site')
# ('run_1607', 'Slip-duplicate', 'EQUALS', np.int64(5), 'per site')
# ('run_1607', 'Slip-duplicate', 'NAND', np.int64(1), 'per site')
# ('run_1607', 'Slip-duplicate', 'ORNOT', np.int64(2), 'per site')
# ('run_1607', 'Slip-duplicate', 'XOR', np.int64(4), 'per site')
# ('run_1608', 'Slip-duplicate', 'NAND', np.int64(1), 'per site')
# ('run_1608', 'Slip-duplicate', 'NOT', np.int64(1), 'per site')
# ('run_1608', 'Slip-duplicate', 'ORNOT', np.int64(2), 'per site')
# ('run_1608', 'Slip-duplicate', 'XOR', np.int64(4), 'per site')
# ('run_1609', 'Slip-duplicate', 'ANDNOT', np.int64(3), 'per site')
# ('run_1609', 'Slip-duplicate', 'EQUALS', np.int64(5), 'per site')
# ('run_1609', 'Slip-duplicate', 'OR', np.int64(3), 'per site')
# ('run_1609', 'Slip-duplicate', 'ORNOT', np.int64(2), 'per site')
# ('run_1609', 'Slip-duplicate', 'XOR', np.int64(4), 'per site')
# ('run_1610', 'Slip-duplicate', 'EQUALS', np.int64(5), 'per site')
# ('run_1610', 'Slip-duplicate', 'NOR', np.int64(4), 'per site')
# ('run_1610', 'Slip-duplicate', 'ORNOT', np.int64(2), 'per site')
# ('run_1610', 'Slip-duplicate', 'XOR', np.int64(4), 'per site')
# ('run_1611', 'Slip-duplicate', 'NAND', np.int64(1), 'per site')
# ('run_1611', 'Slip-duplicate', 'NOT', np.int64(1), 'per site')
# ('run_1611', 'Slip-duplicate', 'OR', np.int64(3), 'per site')
# ('run_1611', 'Slip-duplicate', 'ORNOT', np.int64(2), 'per site')
# ('run_1612', 'Slip-duplicate', 'EQUALS', np.int64(5), 'per site')
# ('run_1612', 'Slip-duplicate', 'NAND', np.int64(1), 'per site')
# ('run_1612', 'Slip-duplicate', 'NOT', np.int64(1), 'per site')
# ('run_1612', 'Slip-duplicate', 'ORNOT', np.int64(2), 'per site')
# ('run_1612', 'Slip-duplicate', 'XOR', np.int64(4), 'per site')
# ('run_1613', 'Slip-duplicate', 'ORNOT', np.int64(2), 'per site')
# ('run_1613', 'Slip-duplicate', 'XOR', np.int64(4), 'per site')
# ('run_1614', 'Slip-duplicate', 'ANDNOT', np.int64(3), 'per site')
# ('run_1614', 'Slip-duplicate', 'EQUALS', np.int64(5), 'per site')
# ('run_1614', 'Slip-duplicate', 'NOT', np.int64(1), 'per site')
# ('run_1614', 'Slip-duplicate', 'ORNOT', np.int64(2), 'per site')
# ('run_1614', 'Slip-duplicate', 'XOR', np.int64(4), 'per site')
# ('run_1615', 'Slip-duplicate', 'EQUALS', np.int64(5), 'per site')
# ('run_1615', 'Slip-duplicate', 'NOR', np.int64(4), 'per site')
# ('run_1615', 'Slip-duplicate', 'ORNOT', np.int64(2), 'per site')
# ('run_1616', 'Slip-duplicate', 'NAND', np.int64(1), 'per site')
# ('run_1617', 'Slip-duplicate', 'EQUALS', np.int64(5), 'per site')
# ('run_1617', 'Slip-duplicate', 'NAND', np.int64(1), 'per site')
# ('run_1618', 'Slip-duplicate', 'NOR', np.int64(4), 'per site')
# ('run_1618', 'Slip-duplicate', 'XOR', np.int64(4), 'per site')
# ('run_1619', 'Slip-duplicate', 'NOR', np.int64(4), 'per site')
# ('run_1740', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1740', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1741', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1741', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1742', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1742', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1743', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1743', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1744', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1744', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1745', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1745', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1746', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1746', 'Long-Ancestor-Control-Treatment', 'NOR', np.int64(4), 'per site')
# ('run_1746', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1747', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1747', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1749', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1750', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1750', 'Long-Ancestor-Control-Treatment', 'NOR', np.int64(4), 'per site')
# ('run_1750', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1751', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1751', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1752', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1752', 'Long-Ancestor-Control-Treatment', 'NOR', np.int64(4), 'per site')
# ('run_1752', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1753', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1753', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1754', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1754', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1755', 'Long-Ancestor-Control-Treatment', 'NOR', np.int64(4), 'per site')
# ('run_1756', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1756', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1757', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1757', 'Long-Ancestor-Control-Treatment', 'NOR', np.int64(4), 'per site')
# ('run_1757', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1758', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1758', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1759', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1759', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1760', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1760', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1761', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1761', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1762', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1762', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1763', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1763', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1764', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1764', 'Long-Ancestor-Control-Treatment', 'NOR', np.int64(4), 'per site')
# ('run_1764', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1765', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1765', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1766', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1766', 'Long-Ancestor-Control-Treatment', 'NOR', np.int64(4), 'per site')
# ('run_1766', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1767', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1767', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1768', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1768', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')
# ('run_1769', 'Long-Ancestor-Control-Treatment', 'EQUALS', np.int64(5), 'per site')
# ('run_1769', 'Long-Ancestor-Control-Treatment', 'NOR', np.int64(4), 'per site')
# ('run_1769', 'Long-Ancestor-Control-Treatment', 'XOR', np.int64(4), 'per site')

# %%
tp.tee(
    sns.relplot,
    data=dfz_[
        dfz_["Generation"] % 16 == 0
    ].reset_index(),
    col="Task",
    row="mutation",
    x="Generation",
    y="Has Task",
    hue="Treatment",
    kind="line",
    # teeplot_postprocess='plt.xscale("log")',
    teeplot_postprocess=f'plt.xlim(0, {least_last_generation})',
    teeplot_subdir=teeplot_subdir,
    errorbar="ci",
)
# Out:
# teeplots/adaptive-evolution-rate-nodirect.ipynb/col=task+errorbar=ci+hue=treatment+kind=line+post=plt-xlim-0-600+row=mutation+viz=relplot+x=generation+y=has-task+ext=.pdf
# teeplots/adaptive-evolution-rate-nodirect.ipynb/col=task+errorbar=ci+hue=treatment+kind=line+post=plt-xlim-0-600+row=mutation+viz=relplot+x=generation+y=has-task+ext=.png

# %%
tp.tee(
    sns.relplot,
    data=dfz_[
        dfz_["Generation"] % 16 == 0
    ].reset_index(),
    col="Components",
    row="mutation",
    x="Generation",
    y="Has Task",
    hue="Treatment",
    kind="line",
    teeplot_postprocess=f"plt.xlim(0, {least_last_generation})",
    teeplot_subdir=teeplot_subdir,
    errorbar="ci",
)
# Out:
# teeplots/adaptive-evolution-rate-nodirect.ipynb/col=components+errorbar=ci+hue=treatment+kind=line+post=plt-xlim-0-600+row=mutation+viz=relplot+x=generation+y=has-task+ext=.pdf
# teeplots/adaptive-evolution-rate-nodirect.ipynb/col=components+errorbar=ci+hue=treatment+kind=line+post=plt-xlim-0-600+row=mutation+viz=relplot+x=generation+y=has-task+ext=.png

# %%
fil = dfz_[
    (dfz_["Generation"] == 599)
]

for task in fil["Task"].unique():
    tab = [
        [
            (
                (fil["Treatment"] == "Baseline-Treatment")
                & (fil["Task"] == task)
                & fil["Has Task"]
            ).sum(),
            (
                (fil["Treatment"] == "Slip-duplicate")
                & (fil["Task"] == task)
                & fil["Has Task"]
            ).sum(),
        ],
        [
            (
                (fil["Treatment"] == "Baseline-Treatment")
                & (fil["Task"] == task)
                & (~fil["Has Task"])
            ).sum(),
            (
                (fil["Treatment"] == "Slip-duplicate")
                & (fil["Task"] == task)
                & (~fil["Has Task"])
            ).sum(),
        ],
    ]
    print(task, tab)
    print("    ", scipy.stats.fisher_exact(tab))
# Out:
# AND [[np.int64(8), np.int64(23)], [np.int64(22), np.int64(7)]]
#      SignificanceResult(statistic=np.float64(0.11067193675889328), pvalue=np.float64(0.00023089337753119202))
# NOT [[np.int64(30), np.int64(20)], [np.int64(0), np.int64(10)]]
#      SignificanceResult(statistic=inf, pvalue=np.float64(0.0007970131314101389))
# OR [[np.int64(16), np.int64(20)], [np.int64(14), np.int64(10)]]
#      SignificanceResult(statistic=np.float64(0.5714285714285714), pvalue=np.float64(0.4295691931947636))
# ANDNOT [[np.int64(11), np.int64(21)], [np.int64(19), np.int64(9)]]
#      SignificanceResult(statistic=np.float64(0.24812030075187969), pvalue=np.float64(0.019096056845063346))
# NAND [[np.int64(30), np.int64(16)], [np.int64(0), np.int64(14)]]
#      SignificanceResult(statistic=inf, pvalue=np.float64(1.6767384375519427e-05))
# ORNOT [[np.int64(29), np.int64(13)], [np.int64(1), np.int64(17)]]
#      SignificanceResult(statistic=np.float64(37.92307692307692), pvalue=np.float64(7.954964600623303e-06))
# NOR [[np.int64(4), np.int64(18)], [np.int64(26), np.int64(12)]]
#      SignificanceResult(statistic=np.float64(0.10256410256410256), pvalue=np.float64(0.00036817673390080477))
# EQUALS [[np.int64(0), np.int64(5)], [np.int64(30), np.int64(25)]]
#      SignificanceResult(statistic=np.float64(0.0), pvalue=np.float64(0.05218554861730598))
# XOR [[np.int64(0), np.int64(5)], [np.int64(30), np.int64(25)]]
#      SignificanceResult(statistic=np.float64(0.0), pvalue=np.float64(0.05218554861730598))

# %%
fil = dfz_[
    (dfz_["Generation"] == 599)
]

for task in fil["Task"].unique():
    tab = [
        [
            (
                (fil["Treatment"] == "Long-Ancestor-Control-Treatment")
                & (fil["Task"] == task)
                & fil["Has Task"]
            ).sum(),
            (
                (fil["Treatment"] == "Slip-duplicate")
                & (fil["Task"] == task)
                & fil["Has Task"]
            ).sum(),
        ],
        [
            (
                (fil["Treatment"] == "Long-Ancestor-Control-Treatment")
                & (fil["Task"] == task)
                & (~fil["Has Task"])
            ).sum(),
            (
                (fil["Treatment"] == "Slip-duplicate")
                & (fil["Task"] == task)
                & (~fil["Has Task"])
            ).sum(),
        ],
    ]
    print(task, tab)
    print("    ", scipy.stats.fisher_exact(tab))
# Out:
# AND [[np.int64(30), np.int64(23)], [np.int64(0), np.int64(7)]]
#      SignificanceResult(statistic=inf, pvalue=np.float64(0.010542535074203227))
# NOT [[np.int64(30), np.int64(20)], [np.int64(0), np.int64(10)]]
#      SignificanceResult(statistic=inf, pvalue=np.float64(0.0007970131314101389))
# OR [[np.int64(30), np.int64(20)], [np.int64(0), np.int64(10)]]
#      SignificanceResult(statistic=inf, pvalue=np.float64(0.0007970131314101389))
# ANDNOT [[np.int64(30), np.int64(21)], [np.int64(0), np.int64(9)]]
#      SignificanceResult(statistic=inf, pvalue=np.float64(0.001935603319138909))
# NAND [[np.int64(30), np.int64(16)], [np.int64(0), np.int64(14)]]
#      SignificanceResult(statistic=inf, pvalue=np.float64(1.6767384375519427e-05))
# ORNOT [[np.int64(30), np.int64(13)], [np.int64(0), np.int64(17)]]
#      SignificanceResult(statistic=inf, pvalue=np.float64(6.185596344065137e-07))
# NOR [[np.int64(22), np.int64(18)], [np.int64(8), np.int64(12)]]
#      SignificanceResult(statistic=np.float64(1.8333333333333333), pvalue=np.float64(0.41175659704810597))
# EQUALS [[np.int64(2), np.int64(5)], [np.int64(28), np.int64(25)]]
#      SignificanceResult(statistic=np.float64(0.35714285714285715), pvalue=np.float64(0.4238099099829697))
# XOR [[np.int64(2), np.int64(5)], [np.int64(28), np.int64(25)]]
#      SignificanceResult(statistic=np.float64(0.35714285714285715), pvalue=np.float64(0.4238099099829697))

# %%
fil = dfz_[
    (dfz_["Generation"] == 599)
]

for components in sorted(fil["Components"].unique()):
    tab = [
        [
            (
                (fil["Treatment"] == "Long-Ancestor-Control-Treatment")
                & (fil["Components"] == components)
                & fil["Has Task"]
            ).sum(),
            (
                (fil["Treatment"] == "Slip-duplicate")
                & (fil["Components"] == components)
                & fil["Has Task"]
            ).sum(),
        ],
        [
            (
                (fil["Treatment"] == "Long-Ancestor-Control-Treatment")
                & (fil["Components"] == components)
                & (~fil["Has Task"])
            ).sum(),
            (
                (fil["Treatment"] == "Slip-duplicate")
                & (fil["Components"] == components)
                & (~fil["Has Task"])
            ).sum(),
        ],
    ]
    print(components, tab)
    print("    ", scipy.stats.fisher_exact(tab))
# Out:
# 1 [[np.int64(60), np.int64(36)], [np.int64(0), np.int64(24)]]
#      SignificanceResult(statistic=inf, pvalue=np.float64(6.632030256515911e-09))
# 2 [[np.int64(60), np.int64(36)], [np.int64(0), np.int64(24)]]
#      SignificanceResult(statistic=inf, pvalue=np.float64(6.632030256515911e-09))
# 3 [[np.int64(60), np.int64(41)], [np.int64(0), np.int64(19)]]
#      SignificanceResult(statistic=inf, pvalue=np.float64(7.009823797510181e-07))
# 4 [[np.int64(24), np.int64(23)], [np.int64(36), np.int64(37)]]
#      SignificanceResult(statistic=np.float64(1.0724637681159421), pvalue=1.0)
# 5 [[np.int64(2), np.int64(5)], [np.int64(28), np.int64(25)]]
#      SignificanceResult(statistic=np.float64(0.35714285714285715), pvalue=np.float64(0.4238099099829697))
